# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
import json

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
import sys  
sys.path.insert(0, '../')
from config import weather_api_key

# Starting URL for Weather Map API Call.
weather_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
print(json.dumps(cities, indent=4))
# Out:
# [
#     "marigot",
#     "yuksekova",
#     "barrow",
#     "taolanaro",
#     "longyearbyen",
#     "hambantota",
#     "busselton",
#     "kachikau",
#     "adrar",
#     "buraydah",
#     "mys shmidta",
#     "hobart",
#     "mataura",
#     "kodiak",
#     "tuktoyaktuk",
#     "albany",
#     "bengkulu",
#     "punta arenas",
#     "trelew",
#     "rikitea",
#     "ponta do sol",
#     "isla mujeres",
#     "almeirim",
#     "acapulco",
#     "tigil",
#     "tamandare",
#     "cherskiy",
#     "kapaa",
#     "buckie",
#     "ushuaia",
#     "belushya guba",
#     "hermanus",
#     "grand river south east",
#     "kahului",
#     "new norfolk",
#     "darhan",
#     "vaitupu",
#     "baherden",
#     "umzimvubu",
#     "rocha",
#     "pevek",
#     "butaritari",
#     "tiksi",
#     "cockburn town",
#     "quatre cocos",
#     "yellowknife",
#     "koraput",
#     "ribeira grande",
#     "castro",
#     "cape town",
#     "illoqqortoormiut",
#     "atuona",
#     "eirunepe",
#     "vila velha",
#     "kambove",
#     "kedrovyy",
#     "puerto ayora",
#     "port-cartier",
#     "evanston",
#     "qaanaaq",
#     "mahebourg",
#     "coihaique",
#     "vilyuysk",
#     "barbar",
#     "upernavik",
#     "dunedin",
#     "athabasca",
#     "port alfred",
#     "bathsheba",
#     "san jeronimo",
#     "tuatapere",
#     "saint george",
#     "tsihombe",
#     "inhambane",
#     "toyooka",
#     "bony",
#     "andros town",
#     "mar del plata",
#     "saldanha",
#     "ahipara",
#     "nikolskoye",
#     "lebu",
#     "sola",
#     "tashla",
#     "igualada",
#     "iqaluit",
#     "iskateley",
#     "moscow",
#     "port elizabeth",
#     "nangong",
#     "jamestown",
#     "olafsvik",
#     "hovd",
#     "raga",
#     "barranca",
#     "carnarvon",
#     "lindi",
#     "matadi",
#     "maksi",
#     "barawe",
#     "hithadhoo",
#     "klaksvik",
#     "bambous virieux",
#     "bluff",
#     "dongsheng",
#     "tahta",
#     "lorengau",
#     "halifax",
#     "tessalit",
#     "seoul",
#     "chokurdakh",
#     "khatanga",
#     "bredasdorp",
#     "vaini",
#     "avarua",
#     "karaul",
#     "achisay",
#     "kavaratti",
#     "thompson",
#     "namibe",
#     "visnes",
#     "saskylakh",
#     "margate",
#     "torbay",
#     "airai",
#     "sangar",
#     "kedrovoye",
#     "pedasi",
#     "havre-saint-pierre",
#     "fort saint james",
#     "srednekolymsk",
#     "port hawkesbury",
#     "faanui",
#     "tasiilaq",
#     "sentyabrskiy",
#     "eslamshahr",
#     "torre-pacheco",
#     "sovetskaya gavan",
#     "kasempa",
#     "norman wells",
#     "jalu",
#     "general pico",
#     "nanortalik",
#     "road town",
#     "valdivia",
#     "ketchikan",
#     "loandjili",
#     "laguna",
#     "shasta lake",
#     "aloleng",
#     "banda aceh",
#     "inverell",
#     "tamiahua",
#     "guasdualito",
#     "louisbourg",
#     "fort nelson",
#     "ghanzi",
#     "wasilla",
#     "vila franca do campo",
#     "asau",
#     "dongtai",
#     "maniitsoq",
#     "meyungs",
#     "hilo",
#     "georgetown",
#     "yenagoa",
#     "ostrovnoy",
#     "kampot",
#     "grindavik",
#     "feijo",
#     "isangel",
#     "kalemie",
#     "xichang",
#     "whitehorse",
#     "moanda",
#     "cam ranh",
#     "saint-philippe",
#     "salalah",
#     "mocambique",
#     "vibo valentia",
#     "yarada",
#     "odesskoye",
#     "flinders",
#     "bunda",
#     "copandaro",
#     "lagoa",
#     "palembang",
#     "sorland",
#     "camargo",
#     "leningradskiy",
#     "kompaniyivka",
#     "arraial do cabo",
#     "taguatinga",
#     "ambilobe",
#     "qaqortoq",
#     "ust-tsilma",
#     "lodja",
#     "iquique",
#     "jiwani",
#     "oildale",
#     "porto novo",
#     "san cristobal",
#     "manono",
#     "beringovskiy",
#     "mount gambier",
#     "shelburne",
#     "umm lajj",
#     "codrington",
#     "karratha",
#     "nome",
#     "kaitangata",
#     "iisaku",
#     "peleduy",
#     "fort saint john",
#     "angoram",
#     "dikson",
#     "sioux lookout",
#     "ilulissat",
#     "talnakh",
#     "riihimaki",
#     "east london",
#     "barabai",
#     "grand centre",
#     "brae",
#     "victoria",
#     "sretensk",
#     "havelock",
#     "bara",
#     "saleaula",
#     "meaford",
#     "camacha",
#     "alice",
#     "fort wellington",
#     "tondano",
#     "barentsburg",
#     "buchanan",
#     "nicoya",
#     "teguldet",
#     "cidreira",
#     "severobaykalsk",
#     "igarka",
#     "kadykchan",
#     "kurush",
#     "cabedelo",
#     "makubetsu",
#     "atar",
#     "nsanje",
#     "barrancabermeja",
#     "rostovka",
#     "avera",
#     "hlobyne",
#     "morros",
#     "lompoc",
#     "mandalgovi",
#     "bonavista",
#     "laje",
#     "esperance",
#     "kieta",
#     "kondinskoye",
#     "dingle",
#     "eyl",
#     "moron",
#     "fundao",
#     "maumere",
#     "venado tuerto",
#     "doha",
#     "deputatskiy",
#     "dragor",
#     "juquia",
#     "constitucion",
#     "mangrol",
#     "warmbad",
#     "biltine",
#     "harrisonville",
#     "llanes",
#     "alice springs",
#     "kaputa",
#     "mabaruma",
#     "belmonte",
#     "hasaki",
#     "chuy",
#     "port blair",
#     "werda",
#     "dunmore town",
#     "praia da vitoria",
#     "lafiagi",
#     "marawi",
#     "shingu",
#     "eckernforde",
#     "tambovka",
#     "auki",
#     "sechura",
#     "emerald",
#     "tomatlan",
#     "ondorhaan",
#     "paamiut",
#     "tres arroyos",
#     "port hardy",
#     "asfi",
#     "ancud",
#     "porto velho",
#     "kubachi",
#     "bucak",
#     "nouadhibou",
#     "tavda",
#     "khandyga",
#     "bulaevo",
#     "sorvag",
#     "severo-kurilsk",
#     "yazman",
#     "husavik",
#     "one hundred mile house",
#     "hami",
#     "kavieng",
#     "poya",
#     "santa brigida",
#     "vardo",
#     "plettenberg bay",
#     "nizhneyansk",
#     "lasa",
#     "cermik",
#     "puerto quijarro",
#     "luderitz",
#     "scarborough",
#     "san patricio",
#     "nevsehir",
#     "kruisfontein",
#     "tingo maria",
#     "bow island",
#     "puerto escondido",
#     "ligayan",
#     "santa fe",
#     "bethel",
#     "zyryanka",
#     "kenai",
#     "pisco",
#     "bria",
#     "attawapiskat",
#     "sisimiut",
#     "cayenne",
#     "hervey bay",
#     "svetlyy",
#     "gunjur",
#     "natalinsk",
#     "bodaybo",
#     "oktyabrskiy",
#     "taoudenni",
#     "vrangel",
#     "toliary",
#     "mantenopolis",
#     "kismayo",
#     "progreso",
#     "satitoa",
#     "naruja",
#     "indore",
#     "surskoye",
#     "coulihaut",
#     "clyde river",
#     "sambava",
#     "maryville",
#     "cozumel",
#     "samalaeulu",
#     "bima",
#     "paris",
#     "san quintin",
#     "rapar",
#     "ukiah",
#     "livingstonia",
#     "vilhena",
#     "kharp",
#     "coihueco",
#     "kloulklubed",
#     "killybegs",
#     "katsuura",
#     "tura",
#     "mahajanga",
#     "fortuna",
#     "valparaiso",
#     "butterworth",
#     "balingasay",
#     "samusu",
#     "walla walla",
#     "bosaso",
#     "grand gaube",
#     "along",
#     "roald",
#     "ardino",
#     "berasia",
#     "linguere",
#     "haines junction",
#     "alofi",
#     "elko",
#     "obera",
#     "skibbereen",
#     "bentiu",
#     "muyezerskiy",
#     "alotau",
#     "comodoro rivadavia",
#     "gwembe",
#     "piacabucu",
#     "agadir",
#     "panino",
#     "pangnirtung",
#     "yining",
#     "cabo san lucas",
#     "komsomolskiy",
#     "summerside",
#     "meulaboh",
#     "key largo",
#     "abha",
#     "vieques",
#     "kenora",
#     "murray bridge",
#     "sao jose da coroa grande",
#     "labuhan",
#     "timberlake",
#     "pouembout",
#     "kiunga",
#     "gualeguay",
#     "atasu",
#     "port-de-paix",
#     "zhigansk",
#     "senneterre",
#     "palabuhanratu",
#     "qandala",
#     "xuddur",
#     "kathu",
#     "tanete",
#     "amderma",
#     "belaya gora",
#     "chaman",
#     "tsienyane",
#     "shumyachi",
#     "bolungarvik",
#     "touros",
#     "tofield",
#     "ixtapa",
#     "kaoma",
#     "falealupo",
#     "bilibino",
#     "aykhal",
#     "basco",
#     "craig",
#     "pangody",
#     "yulara",
#     "superior",
#     "los amates",
#     "sitka",
#     "te anau",
#     "penzance",
#     "tabuk",
#     "broome",
#     "paradise valley",
#     "rio gallegos",
#     "macau",
#     "wewak",
#     "kichera",
#     "tezu",
#     "tam ky",
#     "chabahar",
#     "kutum",
#     "edd",
#     "ferrol",
#     "egvekinot",
#     "bagdarin",
#     "turinsk",
#     "dalmatovo",
#     "herat",
#     "osinovo",
#     "muros",
#     "sebastian",
#     "juli",
#     "nuuk",
#     "azimur",
#     "yate",
#     "chapais",
#     "vila",
#     "mogadishu",
#     "lolua",
#     "pocatello",
#     "macomb",
#     "rawson",
#     "brattleboro",
#     "zhangjiakou",
#     "northam",
#     "sayyan",
#     "qarchak",
#     "lavrentiya",
#     "saint-georges",
#     "registro",
#     "makasar",
#     "college",
#     "fare",
#     "vila do maio",
#     "nhulunbuy",
#     "warud",
#     "sao filipe",
#     "hobyo",
#     "puerto baquerizo moreno",
#     "marabba",
#     "marihatag",
#     "luanda",
#     "mazatlan",
#     "bulgan",
#     "karpathos",
#     "yefira",
#     "roma",
#     "divnomorskoye",
#     "jinchang",
#     "fukue",
#     "kilindoni",
#     "oussouye",
#     "mitchell",
#     "gushikawa",
#     "ingleside",
#     "altay",
#     "kayanga",
#     "fjerritslev",
#     "sheksna",
#     "krasnoselkup",
#     "luba",
#     "puri",
#     "dekoa",
#     "anamur",
#     "sampit",
#     "bergama",
#     "jiroft",
#     "kurskaya",
#     "berlevag",
#     "chulym",
#     "harper",
#     "chara",
#     "phan rang",
#     "princeton",
#     "yumen",
#     "belgrade",
#     "nerja",
#     "locri",
#     "okhotsk",
#     "nipawin",
#     "ouesso",
#     "bangassou",
#     "boyolangu",
#     "evensk",
#     "ngukurr",
#     "san rafael",
#     "shetpe",
#     "yichang",
#     "bay roberts",
#     "cabadiangan",
#     "souillac",
#     "ceyhan",
#     "buala",
#     "broken hill",
#     "tapiramuta",
#     "lakselv",
#     "lekoni",
#     "coahuayana",
#     "necochea",
#     "topolobampo",
#     "palmas bellas",
#     "hailey",
#     "lanja",
#     "arlington",
#     "mehamn",
#     "rapid city",
#     "dalbandin",
#     "duz",
#     "nanakuli",
#     "bonthe",
#     "benguela",
#     "tokur",
#     "suure-jaani",
#     "abu dhabi",
#     "maceio",
#     "rancho palos verdes",
#     "tendukheda",
#     "hato mayor",
#     "ceres",
#     "lamu",
#     "chagda",
#     "aparecida do taboado",
#     "almazar",
#     "fulda",
#     "sibolga",
#     "tommot",
#     "borba",
#     "maxixe",
#     "general roca",
#     "bumba",
#     "kysyl-syr",
#     "mabay",
#     "qingyuan",
#     "cadillac",
#     "port lincoln",
#     "turkistan",
#     "katherine",
#     "dakar",
#     "krechevitsy",
#     "ussel",
#     "tiarei",
#     "san andres",
#     "dumas",
#     "oranjestad",
#     "caravelas",
#     "abu samrah",
#     "mildura",
#     "inuvik",
#     "tabulbah",
#     "kibaya",
#     "zile",
#     "yashkul",
#     "paso del macho",
#     "sao joao da barra",
#     "sant feliu de guixols",
#     "kitsuki",
#     "qandahar",
#     "tarko-sale",
#     "beni",
#     "daru",
#     "faya",
#     "sol-iletsk",
#     "dabou",
#     "kjollefjord",
#     "urengoy",
#     "slave lake",
#     "tynda",
#     "kulhudhuffushi",
#     "uglekamensk",
#     "aklavik",
#     "pochutla",
#     "tasbuget",
#     "camana",
#     "sur",
#     "nizhniy odes",
#     "la sarre",
#     "carhuamayo",
#     "sinjar",
#     "veraval",
#     "sharan",
#     "itoman",
#     "coquimbo",
#     "dalvik",
#     "nisia floresta",
#     "telimele",
#     "siemiatycze",
#     "riyadh",
#     "provideniya",
#     "gisborne",
#     "caruray",
#     "marcona",
#     "colares",
#     "tabiauea",
#     "najran",
#     "santa cruz",
#     "zhicheng",
#     "guiren",
#     "peniche",
#     "pleshanovo",
#     "powell river",
#     "mega",
#     "henties bay",
#     "sahrak",
#     "puerto ayacucho",
#     "storsteinnes",
#     "namtsy",
#     "saint-leu",
#     "manggar",
#     "ati",
#     "dolores",
#     "spas",
#     "la ronge",
#     "ballina",
#     "vestmanna",
#     "kuche",
#     "saint-augustin",
#     "neryungri",
#     "namatanai",
#     "hay river",
#     "marshall",
#     "tambopata",
#     "point fortin",
#     "buctzotz",
#     "viisoara",
#     "sao miguel do araguaia",
#     "flin flon",
#     "bukan",
#     "vao",
#     "geraldton",
#     "gemena",
#     "mangan",
#     "sabang",
#     "saint-pierre",
#     "rehoboth",
#     "requena",
#     "sagua la grande",
#     "sarangani",
#     "areosa",
#     "kyshtovka",
#     "bontang",
#     "panaba",
#     "ratnagiri",
#     "agua branca",
#     "moses lake",
#     "lata",
#     "marrakesh",
#     "svetlaya",
#     "tagbina",
#     "burns lake",
#     "assela",
#     "homer",
#     "saint-paul",
#     "narsaq",
#     "coos bay",
#     "bundaberg",
#     "srivardhan",
#     "parana",
#     "khuzdar",
#     "apaxtla",
#     "ulaangom",
#     "sipoo",
#     "dosso",
#     "kalakamati",
#     "mumford",
#     "byron bay",
#     "carutapera",
#     "aksu",
#     "ducheng",
#     "champerico",
#     "camalu",
#     "guerrero negro",
#     "ahuimanu",
#     "bendigo",
#     "nandu",
#     "yambio",
#     "aden",
#     "ust-kulom",
#     "teya",
#     "saint-francois",
#     "eenhana",
#     "trairi",
#     "naze",
#     "ahumada",
#     "oyek",
#     "mayumba",
#     "sokolo",
#     "ilam",
#     "karamay",
#     "nyurba",
#     "snasa",
#     "bykivka",
#     "tha bo"
# ]

# %%
city_url_test = weather_url + "&q=" + cities[0].replace(" ","+")
city_weather_test = requests.get(city_url_test).json()
print(json.dumps(city_weather_test, indent=4))
# Out:
# {
#     "coord": {
#         "lon": -63.0833,
#         "lat": 18.0667
#     },
#     "weather": [
#         {
#             "id": 802,
#             "main": "Clouds",
#             "description": "scattered clouds",
#             "icon": "03d"
#         }
#     ],
#     "base": "stations",
#     "main": {
#         "temp": 85.1,
#         "feels_like": 91.45,
#         "temp_min": 84.29,
#         "temp_max": 86.22,
#         "pressure": 1019,
#         "humidity": 66
#     },
#     "visibility": 10000,
#     "wind": {
#         "speed": 12.66,
#         "deg": 90
#     },
#     "clouds": {
#         "all": 40
#     },
#     "dt": 1622479685,
#     "sys": {
#         "type": 1,
#         "id": 8801,
#         "country": "MF",
#         "sunrise": 1622453771,
#         "sunset": 1622501057
#     },
#     "timezone": -14400,
#     "id": 3578851,
#     "name": "Marigot",
#     "cod": 200
# }

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marigot
# Processing Record 2 of Set 1 | yuksekova
# Processing Record 3 of Set 1 | barrow
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | longyearbyen
# Processing Record 6 of Set 1 | hambantota
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | kachikau
# City not found. Skipping...
# Processing Record 9 of Set 1 | adrar
# Processing Record 10 of Set 1 | buraydah
# Processing Record 11 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | bengkulu
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | trelew
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | ponta do sol
# Processing Record 22 of Set 1 | isla mujeres
# Processing Record 23 of Set 1 | almeirim
# Processing Record 24 of Set 1 | acapulco
# Processing Record 25 of Set 1 | tigil
# Processing Record 26 of Set 1 | tamandare
# Processing Record 27 of Set 1 | cherskiy
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | buckie
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 1 | kahului
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | darhan
# Processing Record 37 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 1 | baherden
# Processing Record 39 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 1 | rocha
# Processing Record 41 of Set 1 | pevek
# Processing Record 42 of Set 1 | butaritari
# Processing Record 43 of Set 1 | tiksi
# Processing Record 44 of Set 1 | cockburn town
# Processing Record 45 of Set 1 | quatre cocos
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | koraput
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | eirunepe
# Processing Record 4 of Set 2 | vila velha
# Processing Record 5 of Set 2 | kambove
# Processing Record 6 of Set 2 | kedrovyy
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | port-cartier
# Processing Record 9 of Set 2 | evanston
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | coihaique
# Processing Record 13 of Set 2 | vilyuysk
# Processing Record 14 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | dunedin
# Processing Record 17 of Set 2 | athabasca
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | bathsheba
# Processing Record 20 of Set 2 | san jeronimo
# Processing Record 21 of Set 2 | tuatapere
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | inhambane
# Processing Record 25 of Set 2 | toyooka
# Processing Record 26 of Set 2 | bony
# Processing Record 27 of Set 2 | andros town
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | saldanha
# Processing Record 30 of Set 2 | ahipara
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | sola
# Processing Record 34 of Set 2 | tashla
# Processing Record 35 of Set 2 | igualada
# Processing Record 36 of Set 2 | iqaluit
# Processing Record 37 of Set 2 | iskateley
# Processing Record 38 of Set 2 | moscow
# Processing Record 39 of Set 2 | port elizabeth
# Processing Record 40 of Set 2 | nangong
# Processing Record 41 of Set 2 | jamestown
# Processing Record 42 of Set 2 | olafsvik
# Processing Record 43 of Set 2 | hovd
# Processing Record 44 of Set 2 | raga
# Processing Record 45 of Set 2 | barranca
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | lindi
# Processing Record 48 of Set 2 | matadi
# Processing Record 49 of Set 2 | maksi
# Processing Record 50 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 3 | hithadhoo
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | bluff
# Processing Record 5 of Set 3 | dongsheng
# Processing Record 6 of Set 3 | tahta
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | halifax
# Processing Record 9 of Set 3 | tessalit
# Processing Record 10 of Set 3 | seoul
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | vaini
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 3 | achisay
# City not found. Skipping...
# Processing Record 18 of Set 3 | kavaratti
# Processing Record 19 of Set 3 | thompson
# Processing Record 20 of Set 3 | namibe
# Processing Record 21 of Set 3 | visnes
# Processing Record 22 of Set 3 | saskylakh
# Processing Record 23 of Set 3 | margate
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | sangar
# Processing Record 27 of Set 3 | kedrovoye
# Processing Record 28 of Set 3 | pedasi
# Processing Record 29 of Set 3 | havre-saint-pierre
# Processing Record 30 of Set 3 | fort saint james
# Processing Record 31 of Set 3 | srednekolymsk
# Processing Record 32 of Set 3 | port hawkesbury
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | tasiilaq
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | eslamshahr
# Processing Record 37 of Set 3 | torre-pacheco
# Processing Record 38 of Set 3 | sovetskaya gavan
# Processing Record 39 of Set 3 | kasempa
# Processing Record 40 of Set 3 | norman wells
# Processing Record 41 of Set 3 | jalu
# Processing Record 42 of Set 3 | general pico
# Processing Record 43 of Set 3 | nanortalik
# Processing Record 44 of Set 3 | road town
# Processing Record 45 of Set 3 | valdivia
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | loandjili
# Processing Record 48 of Set 3 | laguna
# Processing Record 49 of Set 3 | shasta lake
# Processing Record 50 of Set 3 | aloleng
# Processing Record 1 of Set 4 | banda aceh
# Processing Record 2 of Set 4 | inverell
# Processing Record 3 of Set 4 | tamiahua
# Processing Record 4 of Set 4 | guasdualito
# Processing Record 5 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 4 | fort nelson
# Processing Record 7 of Set 4 | ghanzi
# Processing Record 8 of Set 4 | wasilla
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | asau
# Processing Record 11 of Set 4 | dongtai
# Processing Record 12 of Set 4 | maniitsoq
# Processing Record 13 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 4 | hilo
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | yenagoa
# Processing Record 17 of Set 4 | ostrovnoy
# Processing Record 18 of Set 4 | kampot
# Processing Record 19 of Set 4 | grindavik
# Processing Record 20 of Set 4 | feijo
# Processing Record 21 of Set 4 | isangel
# Processing Record 22 of Set 4 | kalemie
# Processing Record 23 of Set 4 | xichang
# Processing Record 24 of Set 4 | whitehorse
# Processing Record 25 of Set 4 | moanda
# Processing Record 26 of Set 4 | cam ranh
# Processing Record 27 of Set 4 | saint-philippe
# Processing Record 28 of Set 4 | salalah
# Processing Record 29 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 4 | vibo valentia
# Processing Record 31 of Set 4 | yarada
# Processing Record 32 of Set 4 | odesskoye
# Processing Record 33 of Set 4 | flinders
# Processing Record 34 of Set 4 | bunda
# Processing Record 35 of Set 4 | copandaro
# City not found. Skipping...
# Processing Record 36 of Set 4 | lagoa
# Processing Record 37 of Set 4 | palembang
# Processing Record 38 of Set 4 | sorland
# Processing Record 39 of Set 4 | camargo
# Processing Record 40 of Set 4 | leningradskiy
# Processing Record 41 of Set 4 | kompaniyivka
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | taguatinga
# Processing Record 44 of Set 4 | ambilobe
# Processing Record 45 of Set 4 | qaqortoq
# Processing Record 46 of Set 4 | ust-tsilma
# Processing Record 47 of Set 4 | lodja
# Processing Record 48 of Set 4 | iquique
# Processing Record 49 of Set 4 | jiwani
# Processing Record 50 of Set 4 | oildale
# Processing Record 1 of Set 5 | porto novo
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | manono
# Processing Record 4 of Set 5 | beringovskiy
# Processing Record 5 of Set 5 | mount gambier
# Processing Record 6 of Set 5 | shelburne
# Processing Record 7 of Set 5 | umm lajj
# Processing Record 8 of Set 5 | codrington
# Processing Record 9 of Set 5 | karratha
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | kaitangata
# Processing Record 12 of Set 5 | iisaku
# Processing Record 13 of Set 5 | peleduy
# Processing Record 14 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 5 | angoram
# Processing Record 16 of Set 5 | dikson
# Processing Record 17 of Set 5 | sioux lookout
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | talnakh
# Processing Record 20 of Set 5 | riihimaki
# Processing Record 21 of Set 5 | east london
# Processing Record 22 of Set 5 | barabai
# Processing Record 23 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 5 | brae
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | sretensk
# Processing Record 27 of Set 5 | havelock
# Processing Record 28 of Set 5 | bara
# Processing Record 29 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 30 of Set 5 | meaford
# Processing Record 31 of Set 5 | camacha
# Processing Record 32 of Set 5 | alice
# Processing Record 33 of Set 5 | fort wellington
# Processing Record 34 of Set 5 | tondano
# Processing Record 35 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | buchanan
# Processing Record 37 of Set 5 | nicoya
# Processing Record 38 of Set 5 | teguldet
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | severobaykalsk
# Processing Record 41 of Set 5 | igarka
# Processing Record 42 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 43 of Set 5 | kurush
# Processing Record 44 of Set 5 | cabedelo
# Processing Record 45 of Set 5 | makubetsu
# Processing Record 46 of Set 5 | atar
# Processing Record 47 of Set 5 | nsanje
# Processing Record 48 of Set 5 | barrancabermeja
# Processing Record 49 of Set 5 | rostovka
# Processing Record 50 of Set 5 | avera
# Processing Record 1 of Set 6 | hlobyne
# Processing Record 2 of Set 6 | morros
# Processing Record 3 of Set 6 | lompoc
# Processing Record 4 of Set 6 | mandalgovi
# Processing Record 5 of Set 6 | bonavista
# Processing Record 6 of Set 6 | laje
# Processing Record 7 of Set 6 | esperance
# Processing Record 8 of Set 6 | kieta
# Processing Record 9 of Set 6 | kondinskoye
# Processing Record 10 of Set 6 | dingle
# Processing Record 11 of Set 6 | eyl
# Processing Record 12 of Set 6 | moron
# Processing Record 13 of Set 6 | fundao
# Processing Record 14 of Set 6 | maumere
# Processing Record 15 of Set 6 | venado tuerto
# Processing Record 16 of Set 6 | doha
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | dragor
# Processing Record 19 of Set 6 | juquia
# Processing Record 20 of Set 6 | constitucion
# Processing Record 21 of Set 6 | mangrol
# Processing Record 22 of Set 6 | warmbad
# Processing Record 23 of Set 6 | biltine
# Processing Record 24 of Set 6 | harrisonville
# Processing Record 25 of Set 6 | llanes
# Processing Record 26 of Set 6 | alice springs
# Processing Record 27 of Set 6 | kaputa
# Processing Record 28 of Set 6 | mabaruma
# Processing Record 29 of Set 6 | belmonte
# Processing Record 30 of Set 6 | hasaki
# Processing Record 31 of Set 6 | chuy
# Processing Record 32 of Set 6 | port blair
# Processing Record 33 of Set 6 | werda
# Processing Record 34 of Set 6 | dunmore town
# Processing Record 35 of Set 6 | praia da vitoria
# Processing Record 36 of Set 6 | lafiagi
# Processing Record 37 of Set 6 | marawi
# Processing Record 38 of Set 6 | shingu
# Processing Record 39 of Set 6 | eckernforde
# Processing Record 40 of Set 6 | tambovka
# Processing Record 41 of Set 6 | auki
# Processing Record 42 of Set 6 | sechura
# Processing Record 43 of Set 6 | emerald
# Processing Record 44 of Set 6 | tomatlan
# Processing Record 45 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 6 | paamiut
# Processing Record 47 of Set 6 | tres arroyos
# Processing Record 48 of Set 6 | port hardy
# Processing Record 49 of Set 6 | asfi
# Processing Record 50 of Set 6 | ancud
# Processing Record 1 of Set 7 | porto velho
# Processing Record 2 of Set 7 | kubachi
# Processing Record 3 of Set 7 | bucak
# Processing Record 4 of Set 7 | nouadhibou
# Processing Record 5 of Set 7 | tavda
# Processing Record 6 of Set 7 | khandyga
# Processing Record 7 of Set 7 | bulaevo
# Processing Record 8 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 7 | severo-kurilsk
# Processing Record 10 of Set 7 | yazman
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | one hundred mile house
# City not found. Skipping...
# Processing Record 13 of Set 7 | hami
# Processing Record 14 of Set 7 | kavieng
# Processing Record 15 of Set 7 | poya
# Processing Record 16 of Set 7 | santa brigida
# Processing Record 17 of Set 7 | vardo
# Processing Record 18 of Set 7 | plettenberg bay
# Processing Record 19 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 7 | lasa
# Processing Record 21 of Set 7 | cermik
# Processing Record 22 of Set 7 | puerto quijarro
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | scarborough
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | nevsehir
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | tingo maria
# Processing Record 29 of Set 7 | bow island
# Processing Record 30 of Set 7 | puerto escondido
# Processing Record 31 of Set 7 | ligayan
# Processing Record 32 of Set 7 | santa fe
# Processing Record 33 of Set 7 | bethel
# Processing Record 34 of Set 7 | zyryanka
# Processing Record 35 of Set 7 | kenai
# Processing Record 36 of Set 7 | pisco
# Processing Record 37 of Set 7 | bria
# Processing Record 38 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 7 | sisimiut
# Processing Record 40 of Set 7 | cayenne
# Processing Record 41 of Set 7 | hervey bay
# Processing Record 42 of Set 7 | svetlyy
# Processing Record 43 of Set 7 | gunjur
# Processing Record 44 of Set 7 | natalinsk
# Processing Record 45 of Set 7 | bodaybo
# Processing Record 46 of Set 7 | oktyabrskiy
# Processing Record 47 of Set 7 | taoudenni
# Processing Record 48 of Set 7 | vrangel
# Processing Record 49 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 7 | mantenopolis
# Processing Record 1 of Set 8 | kismayo
# Processing Record 2 of Set 8 | progreso
# Processing Record 3 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 4 of Set 8 | naruja
# Processing Record 5 of Set 8 | indore
# Processing Record 6 of Set 8 | surskoye
# Processing Record 7 of Set 8 | coulihaut
# City not found. Skipping...
# Processing Record 8 of Set 8 | clyde river
# Processing Record 9 of Set 8 | sambava
# Processing Record 10 of Set 8 | maryville
# Processing Record 11 of Set 8 | cozumel
# Processing Record 12 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 8 | bima
# Processing Record 14 of Set 8 | paris
# Processing Record 15 of Set 8 | san quintin
# Processing Record 16 of Set 8 | rapar
# Processing Record 17 of Set 8 | ukiah
# Processing Record 18 of Set 8 | livingstonia
# Processing Record 19 of Set 8 | vilhena
# Processing Record 20 of Set 8 | kharp
# Processing Record 21 of Set 8 | coihueco
# Processing Record 22 of Set 8 | kloulklubed
# Processing Record 23 of Set 8 | killybegs
# Processing Record 24 of Set 8 | katsuura
# Processing Record 25 of Set 8 | tura
# Processing Record 26 of Set 8 | mahajanga
# Processing Record 27 of Set 8 | fortuna
# Processing Record 28 of Set 8 | valparaiso
# Processing Record 29 of Set 8 | butterworth
# Processing Record 30 of Set 8 | balingasay
# Processing Record 31 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 8 | walla walla
# Processing Record 33 of Set 8 | bosaso
# Processing Record 34 of Set 8 | grand gaube
# Processing Record 35 of Set 8 | along
# Processing Record 36 of Set 8 | roald
# Processing Record 37 of Set 8 | ardino
# Processing Record 38 of Set 8 | berasia
# Processing Record 39 of Set 8 | linguere
# Processing Record 40 of Set 8 | haines junction
# Processing Record 41 of Set 8 | alofi
# Processing Record 42 of Set 8 | elko
# Processing Record 43 of Set 8 | obera
# Processing Record 44 of Set 8 | skibbereen
# Processing Record 45 of Set 8 | bentiu
# Processing Record 46 of Set 8 | muyezerskiy
# Processing Record 47 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 48 of Set 8 | comodoro rivadavia
# Processing Record 49 of Set 8 | gwembe
# Processing Record 50 of Set 8 | piacabucu
# Processing Record 1 of Set 9 | agadir
# Processing Record 2 of Set 9 | panino
# Processing Record 3 of Set 9 | pangnirtung
# Processing Record 4 of Set 9 | yining
# Processing Record 5 of Set 9 | cabo san lucas
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | summerside
# Processing Record 8 of Set 9 | meulaboh
# Processing Record 9 of Set 9 | key largo
# Processing Record 10 of Set 9 | abha
# Processing Record 11 of Set 9 | vieques
# Processing Record 12 of Set 9 | kenora
# Processing Record 13 of Set 9 | murray bridge
# Processing Record 14 of Set 9 | sao jose da coroa grande
# Processing Record 15 of Set 9 | labuhan
# Processing Record 16 of Set 9 | timberlake
# Processing Record 17 of Set 9 | pouembout
# Processing Record 18 of Set 9 | kiunga
# Processing Record 19 of Set 9 | gualeguay
# Processing Record 20 of Set 9 | atasu
# Processing Record 21 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 22 of Set 9 | zhigansk
# Processing Record 23 of Set 9 | senneterre
# Processing Record 24 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 9 | qandala
# Processing Record 26 of Set 9 | xuddur
# Processing Record 27 of Set 9 | kathu
# Processing Record 28 of Set 9 | tanete
# Processing Record 29 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 9 | belaya gora
# Processing Record 31 of Set 9 | chaman
# Processing Record 32 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 33 of Set 9 | shumyachi
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | touros
# Processing Record 36 of Set 9 | tofield
# Processing Record 37 of Set 9 | ixtapa
# Processing Record 38 of Set 9 | kaoma
# Processing Record 39 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 9 | bilibino
# Processing Record 41 of Set 9 | aykhal
# Processing Record 42 of Set 9 | basco
# Processing Record 43 of Set 9 | craig
# Processing Record 44 of Set 9 | pangody
# Processing Record 45 of Set 9 | yulara
# Processing Record 46 of Set 9 | superior
# Processing Record 47 of Set 9 | los amates
# Processing Record 48 of Set 9 | sitka
# Processing Record 49 of Set 9 | te anau
# Processing Record 50 of Set 9 | penzance
# Processing Record 1 of Set 10 | tabuk
# Processing Record 2 of Set 10 | broome
# Processing Record 3 of Set 10 | paradise valley
# Processing Record 4 of Set 10 | rio gallegos
# Processing Record 5 of Set 10 | macau
# Processing Record 6 of Set 10 | wewak
# Processing Record 7 of Set 10 | kichera
# Processing Record 8 of Set 10 | tezu
# Processing Record 9 of Set 10 | tam ky
# Processing Record 10 of Set 10 | chabahar
# Processing Record 11 of Set 10 | kutum
# Processing Record 12 of Set 10 | edd
# Processing Record 13 of Set 10 | ferrol
# Processing Record 14 of Set 10 | egvekinot
# Processing Record 15 of Set 10 | bagdarin
# Processing Record 16 of Set 10 | turinsk
# Processing Record 17 of Set 10 | dalmatovo
# Processing Record 18 of Set 10 | herat
# Processing Record 19 of Set 10 | osinovo
# Processing Record 20 of Set 10 | muros
# Processing Record 21 of Set 10 | sebastian
# Processing Record 22 of Set 10 | juli
# Processing Record 23 of Set 10 | nuuk
# Processing Record 24 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 25 of Set 10 | yate
# Processing Record 26 of Set 10 | chapais
# Processing Record 27 of Set 10 | vila
# Processing Record 28 of Set 10 | mogadishu
# Processing Record 29 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 10 | pocatello
# Processing Record 31 of Set 10 | macomb
# Processing Record 32 of Set 10 | rawson
# Processing Record 33 of Set 10 | brattleboro
# Processing Record 34 of Set 10 | zhangjiakou
# Processing Record 35 of Set 10 | northam
# Processing Record 36 of Set 10 | sayyan
# Processing Record 37 of Set 10 | qarchak
# Processing Record 38 of Set 10 | lavrentiya
# Processing Record 39 of Set 10 | saint-georges
# Processing Record 40 of Set 10 | registro
# Processing Record 41 of Set 10 | makasar
# Processing Record 42 of Set 10 | college
# Processing Record 43 of Set 10 | fare
# Processing Record 44 of Set 10 | vila do maio
# Processing Record 45 of Set 10 | nhulunbuy
# Processing Record 46 of Set 10 | warud
# Processing Record 47 of Set 10 | sao filipe
# Processing Record 48 of Set 10 | hobyo
# Processing Record 49 of Set 10 | puerto baquerizo moreno
# Processing Record 50 of Set 10 | marabba
# Processing Record 1 of Set 11 | marihatag
# Processing Record 2 of Set 11 | luanda
# Processing Record 3 of Set 11 | mazatlan
# Processing Record 4 of Set 11 | bulgan
# Processing Record 5 of Set 11 | karpathos
# Processing Record 6 of Set 11 | yefira
# City not found. Skipping...
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | divnomorskoye
# Processing Record 9 of Set 11 | jinchang
# Processing Record 10 of Set 11 | fukue
# Processing Record 11 of Set 11 | kilindoni
# Processing Record 12 of Set 11 | oussouye
# Processing Record 13 of Set 11 | mitchell
# Processing Record 14 of Set 11 | gushikawa
# Processing Record 15 of Set 11 | ingleside
# Processing Record 16 of Set 11 | altay
# Processing Record 17 of Set 11 | kayanga
# Processing Record 18 of Set 11 | fjerritslev
# Processing Record 19 of Set 11 | sheksna
# Processing Record 20 of Set 11 | krasnoselkup
# Processing Record 21 of Set 11 | luba
# Processing Record 22 of Set 11 | puri
# Processing Record 23 of Set 11 | dekoa
# City not found. Skipping...
# Processing Record 24 of Set 11 | anamur
# Processing Record 25 of Set 11 | sampit
# Processing Record 26 of Set 11 | bergama
# Processing Record 27 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 28 of Set 11 | kurskaya
# Processing Record 29 of Set 11 | berlevag
# Processing Record 30 of Set 11 | chulym
# Processing Record 31 of Set 11 | harper
# Processing Record 32 of Set 11 | chara
# Processing Record 33 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 34 of Set 11 | princeton
# Processing Record 35 of Set 11 | yumen
# Processing Record 36 of Set 11 | belgrade
# Processing Record 37 of Set 11 | nerja
# Processing Record 38 of Set 11 | locri
# Processing Record 39 of Set 11 | okhotsk
# Processing Record 40 of Set 11 | nipawin
# Processing Record 41 of Set 11 | ouesso
# Processing Record 42 of Set 11 | bangassou
# Processing Record 43 of Set 11 | boyolangu
# Processing Record 44 of Set 11 | evensk
# Processing Record 45 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 11 | san rafael
# Processing Record 47 of Set 11 | shetpe
# Processing Record 48 of Set 11 | yichang
# Processing Record 49 of Set 11 | bay roberts
# Processing Record 50 of Set 11 | cabadiangan
# Processing Record 1 of Set 12 | souillac
# Processing Record 2 of Set 12 | ceyhan
# Processing Record 3 of Set 12 | buala
# Processing Record 4 of Set 12 | broken hill
# Processing Record 5 of Set 12 | tapiramuta
# Processing Record 6 of Set 12 | lakselv
# Processing Record 7 of Set 12 | lekoni
# Processing Record 8 of Set 12 | coahuayana
# Processing Record 9 of Set 12 | necochea
# Processing Record 10 of Set 12 | topolobampo
# Processing Record 11 of Set 12 | palmas bellas
# Processing Record 12 of Set 12 | hailey
# Processing Record 13 of Set 12 | lanja
# Processing Record 14 of Set 12 | arlington
# Processing Record 15 of Set 12 | mehamn
# Processing Record 16 of Set 12 | rapid city
# Processing Record 17 of Set 12 | dalbandin
# Processing Record 18 of Set 12 | duz
# City not found. Skipping...
# Processing Record 19 of Set 12 | nanakuli
# Processing Record 20 of Set 12 | bonthe
# Processing Record 21 of Set 12 | benguela
# Processing Record 22 of Set 12 | tokur
# Processing Record 23 of Set 12 | suure-jaani
# Processing Record 24 of Set 12 | abu dhabi
# Processing Record 25 of Set 12 | maceio
# Processing Record 26 of Set 12 | rancho palos verdes
# Processing Record 27 of Set 12 | tendukheda
# Processing Record 28 of Set 12 | hato mayor
# Processing Record 29 of Set 12 | ceres
# Processing Record 30 of Set 12 | lamu
# Processing Record 31 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 32 of Set 12 | aparecida do taboado
# Processing Record 33 of Set 12 | almazar
# Processing Record 34 of Set 12 | fulda
# Processing Record 35 of Set 12 | sibolga
# Processing Record 36 of Set 12 | tommot
# Processing Record 37 of Set 12 | borba
# Processing Record 38 of Set 12 | maxixe
# Processing Record 39 of Set 12 | general roca
# Processing Record 40 of Set 12 | bumba
# Processing Record 41 of Set 12 | kysyl-syr
# Processing Record 42 of Set 12 | mabay
# Processing Record 43 of Set 12 | qingyuan
# Processing Record 44 of Set 12 | cadillac
# Processing Record 45 of Set 12 | port lincoln
# Processing Record 46 of Set 12 | turkistan
# Processing Record 47 of Set 12 | katherine
# Processing Record 48 of Set 12 | dakar
# Processing Record 49 of Set 12 | krechevitsy
# Processing Record 50 of Set 12 | ussel
# Processing Record 1 of Set 13 | tiarei
# Processing Record 2 of Set 13 | san andres
# Processing Record 3 of Set 13 | dumas
# Processing Record 4 of Set 13 | oranjestad
# Processing Record 5 of Set 13 | caravelas
# Processing Record 6 of Set 13 | abu samrah
# Processing Record 7 of Set 13 | mildura
# Processing Record 8 of Set 13 | inuvik
# Processing Record 9 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 10 of Set 13 | kibaya
# Processing Record 11 of Set 13 | zile
# Processing Record 12 of Set 13 | yashkul
# Processing Record 13 of Set 13 | paso del macho
# Processing Record 14 of Set 13 | sao joao da barra
# Processing Record 15 of Set 13 | sant feliu de guixols
# Processing Record 16 of Set 13 | kitsuki
# Processing Record 17 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 18 of Set 13 | tarko-sale
# Processing Record 19 of Set 13 | beni
# Processing Record 20 of Set 13 | daru
# Processing Record 21 of Set 13 | faya
# Processing Record 22 of Set 13 | sol-iletsk
# Processing Record 23 of Set 13 | dabou
# Processing Record 24 of Set 13 | kjollefjord
# Processing Record 25 of Set 13 | urengoy
# Processing Record 26 of Set 13 | slave lake
# Processing Record 27 of Set 13 | tynda
# Processing Record 28 of Set 13 | kulhudhuffushi
# Processing Record 29 of Set 13 | uglekamensk
# Processing Record 30 of Set 13 | aklavik
# Processing Record 31 of Set 13 | pochutla
# Processing Record 32 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 33 of Set 13 | camana
# Processing Record 34 of Set 13 | sur
# Processing Record 35 of Set 13 | nizhniy odes
# Processing Record 36 of Set 13 | la sarre
# Processing Record 37 of Set 13 | carhuamayo
# Processing Record 38 of Set 13 | sinjar
# Processing Record 39 of Set 13 | veraval
# Processing Record 40 of Set 13 | sharan
# Processing Record 41 of Set 13 | itoman
# Processing Record 42 of Set 13 | coquimbo
# Processing Record 43 of Set 13 | dalvik
# Processing Record 44 of Set 13 | nisia floresta
# Processing Record 45 of Set 13 | telimele
# Processing Record 46 of Set 13 | siemiatycze
# Processing Record 47 of Set 13 | riyadh
# Processing Record 48 of Set 13 | provideniya
# Processing Record 49 of Set 13 | gisborne
# Processing Record 50 of Set 13 | caruray
# Processing Record 1 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 14 | colares
# Processing Record 3 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 14 | najran
# Processing Record 5 of Set 14 | santa cruz
# Processing Record 6 of Set 14 | zhicheng
# Processing Record 7 of Set 14 | guiren
# Processing Record 8 of Set 14 | peniche
# Processing Record 9 of Set 14 | pleshanovo
# Processing Record 10 of Set 14 | powell river
# Processing Record 11 of Set 14 | mega
# Processing Record 12 of Set 14 | henties bay
# Processing Record 13 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 14 of Set 14 | puerto ayacucho
# Processing Record 15 of Set 14 | storsteinnes
# Processing Record 16 of Set 14 | namtsy
# Processing Record 17 of Set 14 | saint-leu
# Processing Record 18 of Set 14 | manggar
# Processing Record 19 of Set 14 | ati
# Processing Record 20 of Set 14 | dolores
# Processing Record 21 of Set 14 | spas
# Processing Record 22 of Set 14 | la ronge
# Processing Record 23 of Set 14 | ballina
# Processing Record 24 of Set 14 | vestmanna
# Processing Record 25 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 14 | saint-augustin
# Processing Record 27 of Set 14 | neryungri
# Processing Record 28 of Set 14 | namatanai
# Processing Record 29 of Set 14 | hay river
# Processing Record 30 of Set 14 | marshall
# Processing Record 31 of Set 14 | tambopata
# Processing Record 32 of Set 14 | point fortin
# Processing Record 33 of Set 14 | buctzotz
# Processing Record 34 of Set 14 | viisoara
# Processing Record 35 of Set 14 | sao miguel do araguaia
# Processing Record 36 of Set 14 | flin flon
# Processing Record 37 of Set 14 | bukan
# Processing Record 38 of Set 14 | vao
# Processing Record 39 of Set 14 | geraldton
# Processing Record 40 of Set 14 | gemena
# Processing Record 41 of Set 14 | mangan
# Processing Record 42 of Set 14 | sabang
# Processing Record 43 of Set 14 | saint-pierre
# Processing Record 44 of Set 14 | rehoboth
# Processing Record 45 of Set 14 | requena
# Processing Record 46 of Set 14 | sagua la grande
# Processing Record 47 of Set 14 | sarangani
# Processing Record 48 of Set 14 | areosa
# Processing Record 49 of Set 14 | kyshtovka
# Processing Record 50 of Set 14 | bontang
# Processing Record 1 of Set 15 | panaba
# Processing Record 2 of Set 15 | ratnagiri
# Processing Record 3 of Set 15 | agua branca
# Processing Record 4 of Set 15 | moses lake
# Processing Record 5 of Set 15 | lata
# Processing Record 6 of Set 15 | marrakesh
# Processing Record 7 of Set 15 | svetlaya
# Processing Record 8 of Set 15 | tagbina
# Processing Record 9 of Set 15 | burns lake
# Processing Record 10 of Set 15 | assela
# City not found. Skipping...
# Processing Record 11 of Set 15 | homer
# Processing Record 12 of Set 15 | saint-paul
# Processing Record 13 of Set 15 | narsaq
# Processing Record 14 of Set 15 | coos bay
# Processing Record 15 of Set 15 | bundaberg
# Processing Record 16 of Set 15 | srivardhan
# Processing Record 17 of Set 15 | parana
# Processing Record 18 of Set 15 | khuzdar
# Processing Record 19 of Set 15 | apaxtla
# City not found. Skipping...
# Processing Record 20 of Set 15 | ulaangom
# Processing Record 21 of Set 15 | sipoo
# Processing Record 22 of Set 15 | dosso
# Processing Record 23 of Set 15 | kalakamati
# Processing Record 24 of Set 15 | mumford
# Processing Record 25 of Set 15 | byron bay
# Processing Record 26 of Set 15 | carutapera
# Processing Record 27 of Set 15 | aksu
# Processing Record 28 of Set 15 | ducheng
# Processing Record 29 of Set 15 | champerico
# Processing Record 30 of Set 15 | camalu
# Processing Record 31 of Set 15 | guerrero negro
# Processing Record 32 of Set 15 | ahuimanu
# Processing Record 33 of Set 15 | bendigo
# Processing Record 34 of Set 15 | nandu
# Processing Record 35 of Set 15 | yambio
# Processing Record 36 of Set 15 | aden
# Processing Record 37 of Set 15 | ust-kulom
# Processing Record 38 of Set 15 | teya
# Processing Record 39 of Set 15 | saint-francois
# Processing Record 40 of Set 15 | eenhana
# Processing Record 41 of Set 15 | trairi
# Processing Record 42 of Set 15 | naze
# Processing Record 43 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 44 of Set 15 | oyek
# Processing Record 45 of Set 15 | mayumba
# Processing Record 46 of Set 15 | sokolo
# Processing Record 47 of Set 15 | ilam
# Processing Record 48 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 49 of Set 15 | nyurba
# Processing Record 50 of Set 15 | snasa
# Processing Record 1 of Set 16 | bykivka
# Processing Record 2 of Set 16 | tha bo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Marigot      MF  18.0667  -63.0833     86.22        66          40
# 1     Yuksekova      TR  37.5736   44.2872     70.43        44           0
# 2        Barrow      US  71.2906 -156.7887     29.52        85         100
# 3  Longyearbyen      SJ  78.2186   15.6401     35.44        69          75
# 4    Hambantota      LK   6.1241   81.1185     81.12        81          81
# 5     Busselton      AU -33.6500  115.3333     51.08        85          93
# 6         Adrar      MR  20.5022  -10.0711    103.57        14          87
# 7      Buraydah      SA  26.3260   43.9750    106.25        10          64
# 8        Hobart      AU -42.8794  147.3294     48.92        75         100
# 9       Mataura      NZ -46.1927  168.8643     40.55        97          91
#
#    Wind Speed Current Description
# 0       12.66    scattered clouds
# 1        5.39           clear sky
# 2       10.18     overcast clouds
# 3        8.05       broken clouds
# 4       20.85       broken clouds
# 5        5.41     overcast clouds
# 6        4.63     overcast clouds
# 7       10.71       broken clouds
# 8        4.00     overcast clouds
# 9        2.06     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
